# %%
### install pandas 
###    !pip install pandas
#import pandas library
import pandas as pd

# %%
data= {'Name': ['Jai','Princi','Gaurav','Anju','Ravi','Natasha','Riya'],
      'Age': [17,17,18,17,18,17,17],
      'Gender': ['M','F','M','M','M','F','F'],
      'Marks': [90,76,'NaN',74,65,'NaN',71]}

## here data is dictionary. Name, Age, Gender and Marks are called key and their values are called value

# %%
df =pd.DataFrame(data)
df
# Out:
#       Name  Age Gender Marks
# 0      Jai   17      M    90
# 1   Princi   17      F    76
# 2   Gaurav   18      M   NaN
# 3     Anju   17      M    74
# 4     Ravi   18      M    65
# 5  Natasha   17      F   NaN
# 6     Riya   17      F    71

# %%
df = pd.read_csv('car driving risk analysis.csv')

# %%
df
# Out:
#     speed  risk
# 0     200    95
# 1      90    20
# 2     300    98
# 3     110    60
# 4     240    72
# 5     115    10
# 6      50     7
# 7     230    85
# 8     190    45
# 9     260    91
# 10    290    82
# 11    185    59
# 12    310    93
# 13     95    18
# 14     30     2

# %%
### to write a csv file you have to use as given below
df.to_csv("shahanur.csv")

# %%
df.head()
# Out:
#    speed  risk
# 0    200    95
# 1     90    20
# 2    300    98
# 3    110    60
# 4    240    72

# %%
df.tail()
# Out:
#     speed  risk
# 10    290    82
# 11    185    59
# 12    310    93
# 13     95    18
# 14     30     2
